# %%
from PIL import Image
from scipy import ndimage
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
a=Image.open('a.jpg')
b=np.array(a)

z=Image.open('b.jpg')
y=np.array(z)
#rotation
x=ndimage.rotate(y,45)
c=ndimage.rotate(b,45)

r=Image.fromarray(x)
d=Image.fromarray(c)
d.save('a1.jpg')
plt.subplot(2,2,1)
plt.imshow(d)

plt.subplot(2,2,2)
plt.imshow(r)


#scaling

# %%
from PIL import Image
from scipy import ndimage
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
a=Image.open('a.jpg')
b=np.array(a)


#rotation

c=ndimage.zoom(b,(.25,.5,1))


d=Image.fromarray(c)
d.save('a1.jpg')

plt.imshow(d)



#scaling
# Out:
# /home/ksb/anaconda3/lib/python3.6/site-packages/scipy/ndimage/interpolation.py:600: UserWarning: From scipy 0.13.0, the output shape of zoom() is calculated with round() instead of int() - for these inputs the size of the returned array has changed.
#   "the returned array has changed.", UserWarning)

# %%
from PIL import Image
from scipy import ndimage
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
a=Image.open('a.jpg')
b=np.array(a)
h,w,c=b.shape
arr=np.array([[1,.5,0],[.5,1,0],[0,0,1]])
ndim=ndimage.affine_transform(b,arr)

d=Image.fromarray(ndim)


plt.imshow(d)
